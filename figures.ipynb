# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D, InputLayer, ZeroPadding2D
from collections import defaultdict
import visualkeras
from PIL import ImageFont

# %%
from keras.applications.vgg19 import VGG19
model = VGG19()
model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_19 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
font = ImageFont.truetype("lmsans10-regular.otf", 32)
visualkeras.layered_view(model, to_file='./figures/vgg19_legend.png', type_ignore=[visualkeras.SpacingDummyLayer],
                         legend=True, font=font, max_z=100, scale_xy=3, scale_z=0.3)
# Out:
# <PIL.Image.Image image mode=RGBA size=2365x982 at 0x1703F7713A0>

# %%
from keras.applications.vgg16 import VGG16
model = VGG16()
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_20 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
font = ImageFont.truetype("lmsans10-regular.otf", 32)
visualkeras.layered_view(model, to_file='./figures/vgg16_legend.png', type_ignore=[visualkeras.SpacingDummyLayer],
                         legend=True, font=font, max_z=100, scale_xy=3, scale_z=0.3)
# Out:
# <PIL.Image.Image image mode=RGBA size=2058x982 at 0x1703FF46F40>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
fig, axs = plt.subplots(2, 6, figsize=(15, 5))

axs[1, 0].set_title('Content image')
axs[1, 0].imshow(mpimg.imread('./images/content-images/isae.jpg'))
axs[1, 1].imshow(mpimg.imread('./results/isae_camionnette.png'))
axs[1, 2].imshow(mpimg.imread('./results/isae_hokusai.png'))
axs[1, 3].imshow(mpimg.imread('./results/isae_kandinsky.png'))
axs[1, 4].imshow(mpimg.imread('./results/isae_mosaic.png'))
axs[1, 5].imshow(mpimg.imread('./results/isae_van_gogh.png'))

axs[0, 1].imshow(mpimg.imread('./images/style-images/camionnette.jpg'))
axs[0, 2].imshow(mpimg.imread('./images/style-images/hokusai.jpg'))
axs[0, 3].imshow(mpimg.imread('./images/style-images/kandinsky.jpg'))
axs[0, 4].imshow(mpimg.imread('./images/style-images/mosaic.jpg'))
axs[0, 5].imshow(mpimg.imread('./images/style-images/van_gogh.jpg'))


for ax in axs[0]:
    ax.set_anchor('S')
    ax.set_axis_off()
    
for ax in axs[1]:
    ax.set_anchor('N')
    ax.set_axis_off()    

    
axs[0, 3].annotate('Style images', xy=(0.5, 1.5), xytext=(0.5, 1.50), xycoords='axes fraction', 
            fontsize=14, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'),
            arrowprops=dict(arrowstyle='-[, widthB=26.0, lengthB=1', lw=.5))

axs[1, 3].annotate('Combined images', xy=(0.5, -.5), xytext=(0.5, -.50), xycoords='axes fraction', 
            fontsize=14, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'),
            arrowprops=dict(arrowstyle='-[, widthB=26.0, lengthB=-1', lw=.5))

plt.savefig('presentation.png', dpi=200, transparent=False, bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 3))

axs[0].imshow(mpimg.imread('./results/1e-1.png'))
axs[1].imshow(mpimg.imread('./results/1e0.png'))
axs[2].imshow(mpimg.imread('./results/1e1.png'))
axs[3].imshow(mpimg.imread('./results/1e2.png'))
axs[4].imshow(mpimg.imread('./results/1e3.png'))

axs[0].set_title("1e-1")
axs[1].set_title("1e0")
axs[2].set_title("1e1")
axs[3].set_title("1e2")
axs[4].set_title("1e3")


for ax in axs:
    ax.set_axis_off()   

plt.tight_layout()
plt.savefig('weight_style.png', dpi=200, transparent=False, bbox_inches='tight')
